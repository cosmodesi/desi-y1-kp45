# %% [markdown]
# # Plot ELG chains
# This jupyter notebook contains some code to make plots of the bestfits and contours for the abacus cubic ELG fits to both the mock mean and individual realisations.

# %%
# Import some necessary modules
import os
import sys
import pickle
import logging
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from chainconsumer import ChainConsumer     

sys.path.append("../../../Barry/")     # Change this so that it points to where you have Barry installed

from barry.samplers import DynestySampler
from barry.config import setup
from barry.models import PowerBeutler2017, CorrBeutler2017
from barry.datasets.dataset_power_spectrum import PowerSpectrum_DESI_KP4
from barry.datasets.dataset_correlation_function import CorrelationFunction_DESI_KP4
from barry.fitter import Fitter
from barry.models.model import Correction
from barry.utils import weighted_avg_and_cov

# Read in the fitter class to get all the info on the fit
pfn = "./plots/desi_kp4_abacus_cubic_ELG/output/desi_kp4_abacus_cubic_ELG.fitter.pkl"
with open(pfn, 'rb') as pickle_file:
    fitter = pickle.load(pickle_file)

# %% [markdown]
# This code segment reads in the chains, plots the bestfit model vs. data and prepares stuff for contour plots and summary files

# %%
logging.info("Creating plots")

fitname = []
datanames = ["CV_Xi_Prerecon", "CV_Xi_Recon", "CV_Pk_Prerecon", "CV_Pk_Recon"]
c = [ChainConsumer(), ChainConsumer(), ChainConsumer(), ChainConsumer()]

# Loop over all the chains
stats = {k: [] for k in datanames}
output = {k: [] for k in datanames}
for posterior, weight, chain, evidence, model, data, extra in fitter.load():

    # Get the realisation number and redshift bin
    if "CV" not in extra["name"]:
        continue
    recon_bin = 0 if "Prerecon" in extra["name"] else 1
    data_bin = 0 if "Xi" in extra["name"] else 1
    realisation = str(extra["name"].split()[-1]) if "realisation" in extra["name"] else "mean"
    chain_bin = int(2.0 * data_bin + recon_bin)
    print(extra["name"], recon_bin, data_bin, chain_bin, realisation)
    
    # Store the chain in a dictionary with parameter names
    df = pd.DataFrame(chain, columns=model.get_labels())

    # Compute alpha_par and alpha_perp for each point in the chain
    alpha_par, alpha_perp = model.get_alphas(df["$\\alpha$"].to_numpy(), df["$\\epsilon$"].to_numpy())
    df["$\\alpha_\\parallel$"] = alpha_par
    df["$\\alpha_\\perp$"] = alpha_perp

    # Get the MAP point and set the model up at this point
    model.set_data(data)
    r_s = model.camb.get_data()["r_s"]
    max_post = posterior.argmax()
    params = df.loc[max_post]
    params_dict = model.get_param_dict(chain[max_post])
    for name, val in params_dict.items():
        model.set_default(name, val)

    # Get some useful properties of the fit, and plot the MAP model against the data if it's the mock mean or realisation 10 (chosen randomly!)
    display = True if realisation == "mean" or realisation == "10" else False
    new_chi_squared, dof, bband, mods, smooths = model.plot(params_dict, display=display)

    # Add the chain or MAP to the Chainconsumer plots
    extra.pop("realisation", None)
    if realisation == "mean":
        c[chain_bin].add_chain(df, weights=weight, **extra, plot_contour=True, plot_point=False, show_as_1d_prior=False)
    else:
        c[chain_bin].add_marker(params, **extra, marker_size=80)

    # Compute some summary statistics and add them to a dictionary
    mean, cov = weighted_avg_and_cov(
        df[
            [
                "$\\alpha_\\parallel$",
                "$\\alpha_\\perp$",
                "$\\Sigma_{nl,||}$",
                "$\\Sigma_{nl,\\perp}$",
            ]
        ],
        weight,
        axis=0,
    )

    corr = cov[1, 0] / np.sqrt(cov[0, 0] * cov[1, 1])
    stats[datanames[chain_bin]].append(
        [mean[0], mean[1], np.sqrt(cov[0, 0]), np.sqrt(cov[1, 1]), corr, new_chi_squared, mean[2], mean[3]]
    )
    output[datanames[chain_bin]].append(
        f"{realisation:s}, {mean[0]:6.4f}, {mean[1]:6.4f}, {mean[2]:6.4f}, {mean[3]:6.4f}, {np.sqrt(cov[0, 0]):6.4f}, {np.sqrt(cov[1, 1]):6.4f}, {corr:7.3f}, {r_s:7.3f}, {new_chi_squared:7.3f}, {dof:4d}"
    )
# Out:
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon mock mean 0 1 2 mean
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 0 0 1 2 0
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 1 0 1 2 1
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 2 0 1 2 2
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 3 0 1 2 3
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 4 0 1 2 4
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 5 0 1 2 5
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 6 0 1 2 6
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 7 0 1 2 7
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 8 0 1 2 8
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 9 0 1 2 9
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 10 0 1 2 10
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 11 0 1 2 11
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 12 0 1 2 12
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 13 0 1 2 13
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 14 0 1 2 14
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 15 0 1 2 15
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 16 0 1 2 16
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 17 0 1 2 17
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 18 0 1 2 18
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 19 0 1 2 19
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 20 0 1 2 20
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 21 0 1 2 21
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 22 0 1 2 22
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 23 0 1 2 23
# DESI KP4 Abacus CubicBox CV Pk ELG Prerecon realisation 24 0 1 2 24
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon mock mean 0 0 0 mean
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 0 0 0 0 0
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 1 0 0 0 1
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 2 0 0 0 2
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 3 0 0 0 3
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 4 0 0 0 4
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 5 0 0 0 5
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 6 0 0 0 6
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 7 0 0 0 7
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 8 0 0 0 8
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 9 0 0 0 9
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 10 0 0 0 10
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 11 0 0 0 11
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 12 0 0 0 12
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 13 0 0 0 13
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 14 0 0 0 14
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 15 0 0 0 15
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 16 0 0 0 16
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 17 0 0 0 17
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 18 0 0 0 18
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 19 0 0 0 19
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 20 0 0 0 20
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 21 0 0 0 21
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 22 0 0 0 22
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 23 0 0 0 23
# DESI KP4 Abacus CubicBox CV Xi ELG Prerecon realisation 24 0 0 0 24
# DESI KP4 Abacus CubicBox CV Pk ELG Recon mock mean 1 1 3 mean
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 0 1 1 3 0
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 1 1 1 3 1
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 2 1 1 3 2
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 3 1 1 3 3
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 4 1 1 3 4
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 5 1 1 3 5
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 6 1 1 3 6
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 7 1 1 3 7
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 8 1 1 3 8
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 9 1 1 3 9
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 10 1 1 3 10
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 11 1 1 3 11
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 12 1 1 3 12
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 13 1 1 3 13
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 14 1 1 3 14
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 15 1 1 3 15
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 16 1 1 3 16
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 17 1 1 3 17
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 18 1 1 3 18
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 19 1 1 3 19
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 20 1 1 3 20
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 21 1 1 3 21
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 22 1 1 3 22
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 23 1 1 3 23
# DESI KP4 Abacus CubicBox CV Pk ELG Recon realisation 24 1 1 3 24
# DESI KP4 Abacus CubicBox CV Xi ELG Recon mock mean 1 0 1 mean
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 0 1 0 1 0
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 1 1 0 1 1
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 2 1 0 1 2
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 3 1 0 1 3
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 4 1 0 1 4
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 5 1 0 1 5
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 6 1 0 1 6
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 7 1 0 1 7
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 8 1 0 1 8
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 9 1 0 1 9
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 10 1 0 1 10
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 11 1 0 1 11
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 12 1 0 1 12
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 13 1 0 1 13
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 14 1 0 1 14
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 15 1 0 1 15
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 16 1 0 1 16
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 17 1 0 1 17
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 18 1 0 1 18
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 19 1 0 1 19
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 20 1 0 1 20
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 21 1 0 1 21
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 22 1 0 1 22
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 23 1 0 1 23
# DESI KP4 Abacus CubicBox CV Xi ELG Recon realisation 24 1 0 1 24

# %% [markdown]
# Plot the contour plots and output the summary statistics

# %%
def plot_errors(stats):

    nstats = len(stats)
    means = np.mean(stats, axis=0)
    covs = np.cov(stats, rowvar=False)
    corr = covs[0, 1] / np.sqrt(covs[0, 0] * covs[1, 1])

    labels = [r"$\sigma_{\alpha,||}$", r"$\sigma_{\alpha,\perp}$", r"$\rho(\alpha_{||},\alpha_{\perp})$"]
    colors = ["r", "b", "g"]
    fig, axes = plt.subplots(figsize=(7, 2), nrows=1, ncols=3, sharey=True, squeeze=False)
    plt.subplots_adjust(left=0.1, top=0.95, bottom=0.05, right=0.95, hspace=0.3)
    for ax, vals, avgs, stds, l, c in zip(
        axes.T, np.array(stats).T[2:5], means[2:5], [np.sqrt(covs[0, 0]), np.sqrt(covs[1, 1]), corr], labels, colors
    ):

        ax[0].hist(vals, 10, color=c, histtype="stepfilled", alpha=0.2, density=False, zorder=0)
        ax[0].hist(vals, 10, color=c, histtype="step", alpha=1.0, lw=1.3, density=False, zorder=1)
        ax[0].axvline(avgs, color="k", ls="--", zorder=2)
        ax[0].axvline(stds, color="k", ls=":", zorder=2)
        ax[0].set_xlabel(l)

    axes[0, 0].set_ylabel(r"$N_{\mathrm{mocks}}$")

    plt.show()

    return nstats, means, covs, corr

truth = {"$\\alpha$": 1.0, "$\\epsilon$": 0, "$\\alpha_\\perp$": 1.0, "$\\alpha_\\parallel$": 1.0}
for chain_bin in range(len(c)):
    print(datanames[chain_bin])
    c[chain_bin].plotter.plot(
        truth=truth,
        parameters=["$\\alpha_\\parallel$", "$\\alpha_\\perp$"],
        legend=False,
        display=True,
        figsize=(6,6)
    )

    # Plot histograms of the errors and r_off
    nstats, means, covs, corr = plot_errors(stats[datanames[chain_bin]])
    
    # Save all the numbers to a file
    with open("./plots/desi_kp4_abacus_cubic_ELG/output/Barry_fit_" + datanames[chain_bin] + ".txt", "w") as f:
        f.write(
            "# Realisation, alpha_par, alpha_perp, Sigma_nl_par, Sigma_nl_perp, sigma_alpha_par, sigma_alpha_perp, corr_alpha_par_perp, rd_of_template, bf_chi2, dof\n"
        )
        for l in output[datanames[chain_bin]]:
            f.write(l + "\n")

        # And now the average of all the individual realisations
        f.write("# ---------------------------------------------------\n")
        f.write(
            "# <alpha_par>, <alpha_perp>, <Sigma_nl_par>, <Sigma_nl_perp>, <sigma_alpha_par>, <sigma_alpha_perp>, <corr_alpha_par_perp>, std_alpha_par, std_alpha_perp, corr_alpha_par_perp, <bf_chi2>\n"
        )
        f.write(
            f"{means[0]:6.4f}, {means[1]:6.4f}, {means[6]:6.4f}, {means[7]:6.4f}, {means[2]:6.4f}, {means[3]:6.4f}, {means[4]:6.4f}, {np.sqrt(covs[0, 0]):6.4f}, {np.sqrt(covs[1, 1]):6.4f}, {corr:6.4f}, {means[5]:7.3f}\n"
        )
# Out:
# CV_Xi_Prerecon
# CV_Xi_Recon
# CV_Pk_Prerecon
# CV_Pk_Recon
